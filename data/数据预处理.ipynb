# %%
from google.colab import drive
import os
drive.mount('/content/gdrive/')
path = "./gdrive/My Drive/Colab Notebooks/金融大数据"
os.chdir(path)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive/

# %%
import pandas as pd
import jieba
import re
from collections import Counter

jieba.load_userdict('user_dict.txt')
# Out:
# Building prefix dict from the default dictionary ...
# Dumping model to file cache /tmp/jieba.cache
# Loading model cost 0.932 seconds.
# Prefix dict has been built successfully.

# %% [markdown]
# ## 数据分析

# %% [markdown]
# ### 加载数据集

# %%
data_raw = pd.read_csv("raw_data/股评数据.csv",sep = '\t', header = None, encoding="gbk")

# %%
print(data_raw.head())
# Out:
#                                                    0
# 0  9   走强需要时日，但是，价值明摆着呢。以下为问答私密内容，你已经解锁获得查看权限T+0，...
# 1  9   详细回答见私密部分。以下为问答私密内容，你已经解锁获得查看权限该股具有非常强的代表性...
# 2  1   详细回答见私密部分。以下为问答私密内容，你已经解锁获得查看权限新疆板块龙头品种，还可...
# 3  1   详细回答见私密部分。以下为问答私密内容，你已经解锁获得查看权限强势震荡,,,,,,,...
# 4  0   详细回答见私密部分。以下为问答私密内容，你已经解锁获得查看权限连续大涨之后出现一定的...

# %% [markdown]
# ### 设置停用词
# 第一个停用词范围比较广，给聚类用；第二个只删除了一些废话比如“您已解锁....”和标点符号、数字，连贯性比较好，给bert用。

# %%
# 根据stopwords.txt创建一个停用词表

stopwords1 = [line.strip() for line in open('stopwords.txt',encoding='UTF-8').readlines()]
stopwords2 = [line.strip() for line in open('stopwords2.txt',encoding='UTF-8').readlines()]

# %%
data_raw.loc[5][0]
# Out:
# '1   详细回答见私密部分。以下为问答私密内容，你已经解锁获得查看权限算是热门板块之一，还不错！,,,,,,,,,,,,,,,,,,,,,,,'

# %%
def split(text):
    #害，我让用'\t'分割,最后给我的是仨空格分割的
    lst = text.strip().split('   ')
    return lst

# %% [markdown]
# 清洗数据，包括去掉停用词、删掉数字、分词

# %%
def cleaner(sentence, idx = 1):
    if idx == 1:
        stopwords = stopwords1
    else:
        stopwords = stopwords2
    s = re.sub("\d+","",sentence)
    words = jieba.cut(s)
    outStr = ''
    for word in words:
        if word not in stopwords:
            outStr += word
            outStr += ' '
    return outStr[:-1]

# %%
def data_proccessing(df):
    res_x = []
    res_y = []
    res_for_bert = []
    for index, row in df.iterrows():
        try:
            y,x = split(row[0])
            if(y == '0' or y == '1' or y == '9'):
                x1 = cleaner(x)
                res_y.append(y)
                res_x.append(x1)
                res_for_bert.append(cleaner(x, 2))
        except:
            continue
    return res_x, res_for_bert, res_y

# %% [markdown]
# X1用于聚类，X2用于训练bert

# %%
X1,X2,Y = data_proccessing(data_raw)

# %%
print(len(X1),len(Y))
# Out:
# 19978 19978

# %%
print(X1[0:5])
print(X2[0:5])
# Out:
# ['走强 时日 价值 明摆着 T 期权 注册 制 题材 兑现 至少 涨停', '该股 强 代表性 加速 上涨 涨停 持股', '新疆 板块 龙头 品种 持有', '强势 震荡', '连续 大涨 下跌 属 反复 区域 低点']
# ['走强 需要 时日 但是 价值 明摆着 呢 T 期权 注册 制 每个 题材 兑现 都 至少 一个 涨停', '该股 具有 非常 强 的 代表性 正在 加速 上涨 涨停 后 继续 持股', '新疆 板块 龙头 品种 还 可 继续 持有 一下', '强势 震荡', '连续 大涨 之后 出现 一定 的 下跌 属 正常 还有 反复 不过 目前 区域 绝不 是 低点']

# %%
my_dict = {0:Y,1:X2}
df_c3 = pd.DataFrame(my_dict)

# %%
df_c3.head()
# Out:
#    0                                                  1
# 0  9  走强 需要 时日 但是 价值 明摆着 呢 T 期权 注册 制 每个 题材 兑现 都 至少 一...
# 1  9               该股 具有 非常 强 的 代表性 正在 加速 上涨 涨停 后 继续 持股
# 2  1                           新疆 板块 龙头 品种 还 可 继续 持有 一下
# 3  1                                              强势 震荡
# 4  0    连续 大涨 之后 出现 一定 的 下跌 属 正常 还有 反复 不过 目前 区域 绝不 是 低点

# %% [markdown]
# 未经过聚类的数据

# %%
df_c3.to_csv("data3.csv",sep = "\t",index=None)

# %% [markdown]
# ### 样本分析

# %%
cls = list(set(Y))

# %%
print(cls)
# Out:
# ['0', '1', '9']

# %%
Counter(Y)
# Out:
# Counter({'0': 1825, '1': 13761, '9': 4392})

# %%
X_cls1 = []
X_o = []
Y_o = []
Xb_cls1 = []
Xb_o = []
for index, i in enumerate(Y):
    if(i == '1'):
        X_cls1.append(X1[index])
        Xb_cls1.append(X2[index])
    else:
        X_o.append(X1[index])
        Xb_o.append(X2[index])
        Y_o.append(i)

# %%
print(len(X_cls1),len(Y_o))
# Out:
# 13761 6217

# %%
print(X_cls1[0])
print(Xb_cls1[0])
# Out:
# 新疆 板块 龙头 品种 持有
# 新疆 板块 龙头 品种 还 可 继续 持有 一下

# %% [markdown]
# 把"1"聚成4类比较合适

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import PCA
from sklearn.cluster import Birch,KMeans
from sklearn.manifold import TSNE

# %%
tv = TfidfVectorizer(use_idf=True, smooth_idf=True, norm=None)

# %%
train_texts = X_cls1

# %%
tv_fit = tv.fit_transform(train_texts)

# %%
tv_fit.toarray().shape
# Out:
# (13761, 13412)

# %%
weight = tv_fit.toarray()

# %%
print(weight[0])
# Out:
# [0. 0. 0. ... 0. 0. 0.]

# %%
def matrixPCA(weight,dimension):
    pca = PCA(n_components = dimension)  # 初始化PCA
    pcaMatrix = pca.fit_transform(weight)        # 返回降维后的数据
    print("降维之前的权重维度：",weight.shape)
    print("降维之后的权重维度：",pcaMatrix.shape)
    return pcaMatrix

def birch(matrix,k):
    clusterer = Birch(n_clusters=k)  # 分成簇的个数
    y = clusterer.fit_predict(matrix)    # 聚类结果
    return y

def kmeans(matrix,k):
    clusterer = KMeans(n_clusters=k)  # 分成簇的个数
    y = clusterer.fit_predict(matrix)
    return y

# %%
weightPCA = weight
weightPCA = matrixPCA(weight, dimension = 512)
# Out:
# 降维之前的权重维度： (13761, 13412)
# 降维之后的权重维度： (13761, 512)

# %%
print(weightPCA[0])
# Out:
# [-1.27434849e+00 -1.13420566e+00  2.84981197e-01  3.42630524e-01
#  -9.25764098e-01 -1.60719768e-01  4.35836330e-01  1.05837526e-01
#   8.68074093e-01  9.11201192e-01  1.15329485e+00 -9.16891752e-01
#   1.11107275e+00  6.54904865e-01  3.08053611e-01 -2.71830159e-01
#  -4.68442604e-01  8.14944529e-01 -3.61336211e-01  8.91889998e-01
#   6.12513035e-01 -6.70922255e-01  3.96063184e-01  2.81382109e-01
#   4.95584878e-01  9.50510307e-01 -4.64765644e-01  2.23430889e-01
#  -5.45293409e-01 -3.28512859e-01 -3.66242094e-02 -8.48986843e-02
#   1.88636504e-01 -2.03895511e-01 -7.37142017e-01 -1.08852151e+00
#  -6.19161987e-01 -2.00650412e-01 -3.88990217e-01  8.27872397e-01
#   2.26167280e-01 -9.83112974e-01  1.35044911e-01  1.15292587e-02
#  -5.29821500e-01 -6.63217203e-01 -1.34164518e-01  7.46760163e-01
#   1.17855925e+00 -2.12175990e-01 -8.79652307e-01 -3.27961645e-01
#   1.58663796e-02 -5.48323312e-01  5.49722443e-01  1.80065612e-01
#  -9.31140098e-01  7.35890077e-01 -5.32229424e-01  4.55673481e-01
#  -1.31417811e-01 -1.12626289e-01  8.95648964e-01 -9.79855496e-01
#  -8.68850358e-02 -4.72696278e-01  8.65244606e-01  5.55436875e-01
#   1.09767650e-01 -4.06852020e-01  3.43539847e-01 -1.45465319e-01
#   4.33679127e-01  5.48319794e-01 -9.63168478e-02 -1.99198895e-01
#   2.52616854e-01 -5.81259275e-01  6.81164059e-02  1.53698641e-01
#  -1.58611097e-01 -6.77542903e-02  2.85085495e-01 -3.23276678e-01
#  -3.08773622e-01 -2.25897391e-01 -3.68969214e-01  8.91388838e-02
#  -2.97853358e-01 -4.81286833e-01 -4.39768922e-01  1.50923976e-01
#   6.30991021e-02 -1.94257661e-01  3.20961387e-01 -6.52025450e-01
#  -1.50284088e-01 -1.84919991e-02 -3.66899434e-01 -3.79868853e-01
#   1.29982842e-01 -1.92303943e-01 -2.80963214e-01  3.44613496e-01
#  -2.09537296e-01  2.75222887e-01 -5.54781215e-01  3.08205553e-01
#  -3.43756397e-01 -1.54141999e-01 -2.02318161e-01  2.84684883e-01
#   5.62730709e-01  2.41618619e-03 -4.59551679e-01  7.88761105e-01
#  -8.27374369e-01  4.71887366e-01 -2.13489184e-01 -1.91126870e-01
#  -2.80815879e-02 -1.14880519e-02  4.44040392e-01  1.02222617e-01
#  -2.95810430e-01  5.12088516e-01  3.53710766e-01  4.24776501e-01
#  -7.07891735e-01  3.86868707e-01 -4.37708304e-01  4.93656494e-01
#   1.90351231e-01  2.15540372e-01  3.23022970e-01  3.56967719e-01
#   3.07921125e-02  4.29932769e-01 -2.50766953e-02 -1.19772557e-01
#  -6.65810979e-01  1.13105359e-01  2.03650620e-01 -5.99294374e-01
#   3.92065358e-01  2.48096356e-01 -6.16690260e-01  6.68825326e-01
#   2.06100910e-01  2.17075769e-01  1.20386449e-01 -2.59082407e-01
#  -5.18517621e-02 -1.79760597e-01 -3.92317105e-01  6.92531992e-01
#  -3.23690934e-01  8.93765675e-02 -2.23374277e-01 -9.74132529e-01
#   2.54487379e-01 -7.00357762e-01  7.19026873e-01  3.73632815e-01
#   7.99235970e-01  2.86443678e-01 -4.23674790e-01 -3.29816758e-01
#  -3.01894742e-01 -2.34281697e-02  3.79625947e-01  8.50227935e-01
#  -4.17560653e-02  5.23166440e-01  2.92593907e-01 -5.23921080e-01
#  -8.46053247e-02 -1.73131379e-01  7.26383412e-01  1.38677659e+00
#   2.99026823e-01 -3.15865647e-01 -1.86670483e-01 -6.43144527e-02
#   8.20048915e-01 -2.35087085e-02  4.73989943e-01 -1.02333002e+00
#  -8.74198573e-01 -4.20039311e-01 -7.27594571e-01  8.15278895e-02
#   4.35977811e-01 -4.34378153e-01 -4.78980720e-01  1.35987348e-01
#   6.27085260e-02  4.13458034e-01  1.22392907e-01  3.02371814e-01
#   9.14461116e-01  2.98617278e-01 -7.21140345e-02  3.22475021e-02
#  -3.79844838e-01  4.69809410e-01  4.78651516e-01 -1.71158208e-02
#  -3.89576368e-01  3.13739824e-01  9.44785157e-01 -5.12230591e-01
#   6.19356599e-02  3.27697133e-01  9.34107158e-01 -2.75348499e-02
#  -6.00978366e-01  7.46440680e-02  5.96867422e-02 -1.14225752e-02
#   1.50077172e-01 -9.99042265e-02 -1.67292815e-01  3.43290783e-02
#  -1.36364464e-01  3.26448098e-02 -4.61923819e-01 -6.69981872e-02
#   2.27104457e-01 -2.66663014e-02 -2.01458593e-01  3.96214880e-01
#  -6.63520860e-03 -2.92120963e-01 -4.16200847e-02 -7.61815039e-02
#   2.73346921e-01 -2.94971302e-01  5.64343748e-01  6.13639485e-01
#  -1.75432417e-01 -2.73863132e-01  3.37335522e-01 -3.56429710e-01
#  -1.49075419e-01  9.76284301e-02  4.84124752e-02  6.34729476e-01
#   6.41908735e-01 -3.59639762e-02  1.90609040e-01  1.91119120e-01
#  -5.57348886e-01  5.98703744e-01  3.81518934e-01  3.42333616e-01
#  -3.63551856e-02  4.39395752e-01 -1.39401268e-02  1.41443599e-01
#  -1.12989883e-01  1.28459154e-01  4.03769533e-01 -2.51037810e-01
#  -4.86665712e-01  4.80944668e-01 -2.84784673e-01  3.07080848e-01
#   6.58061080e-02 -6.34156646e-02  6.09421144e-03 -8.25861306e-03
#   2.96545137e-01  4.05772641e-01  6.49174530e-02  2.59854416e-01
#   1.67239167e-01 -2.72491963e-02  1.20244152e-01 -1.63452432e-01
#   6.40823461e-01 -2.11709667e-01  1.43427328e-01 -3.54689093e-01
#   4.24758456e-01 -2.08263815e-01  1.01430919e-01  1.14651475e-01
#  -2.35411681e-02  2.24932008e-01  4.44287362e-02  5.43781100e-02
#   3.46937053e-01  6.58523797e-02 -3.16796091e-01  5.32716034e-01
#   2.57507284e-01 -1.53592421e-01 -2.20193420e-03  1.49340483e-01
#   8.17094219e-02 -3.70973558e-01  2.83271282e-01 -1.42484214e-01
#  -7.08055781e-02 -3.93776628e-02  3.96004276e-01  4.84934060e-01
#  -1.17674204e-01 -4.76821707e-01 -1.75448679e-01 -4.80414106e-02
#  -2.59399852e-01 -1.81664534e-01 -9.81066625e-02  1.62863318e-01
#  -1.71873765e-01  2.75006251e-01 -2.46040964e-01  2.32235998e-01
#   1.34619185e-01  4.25342490e-01  2.14259622e-01  4.63407241e-02
#  -9.93526810e-02 -8.99655504e-02  2.76023099e-01  7.64070098e-02
#  -4.49740329e-01 -6.33722534e-02 -5.27701622e-02  2.28090594e-02
#   3.90376858e-01 -4.73277855e-01  4.78294068e-01  1.45627563e-01
#   2.36564749e-01  4.94442887e-02  2.54588602e-01 -3.23958828e-01
#  -4.30124050e-01  7.83794250e-01  2.02477916e-01 -4.84901152e-01
#  -4.65938731e-04 -8.88187658e-01  3.13505462e-01 -1.93720901e-02
#   4.13923106e-01 -7.03614781e-02  5.32436296e-01  2.90612729e-01
#   1.67510116e-01 -1.90435274e-01  2.13385106e-01  3.78763314e-01
#  -8.67522899e-02 -1.79325562e-01 -4.47083478e-01  4.79548007e-01
#  -2.69289563e-01 -1.36696191e-01 -5.35488053e-02  4.20022562e-01
#   1.16662086e-01 -1.23192721e-01 -1.38226826e-01  3.27384011e-01
#  -2.55868895e-01 -3.31406004e-02  3.48344067e-01  3.24042533e-01
#  -4.87818821e-01 -5.74178713e-01  2.85770033e-01  4.59992699e-01
#  -1.23256864e-02 -7.98108350e-02 -9.53079718e-02  1.29794288e-01
#  -9.02991497e-02  9.75599898e-02  6.40835193e-01  6.73431960e-01
#   2.41442632e-02  5.72957919e-01 -3.01490686e-01  3.38410620e-04
#  -4.05851184e-01  9.51788587e-02  2.99644854e-01 -3.78279725e-01
#   5.59086781e-01 -3.30985891e-01  3.61631211e-01  2.77637191e-01
#   4.07782250e-01 -2.52572428e-01  3.34337430e-02  3.16624197e-01
#  -7.77996790e-02  2.28201818e-03 -4.99009464e-03  2.96718754e-01
#   1.09034449e-01 -1.17179371e-01  7.34791515e-01  2.27882377e-01
#   2.34800653e-01 -2.92275920e-01 -1.60692848e-01  7.49926358e-01
#   2.75258877e-01 -1.24066522e-01  1.30919556e-01 -5.80757624e-02
#   1.93027277e-01 -1.74110482e-01 -7.30279146e-02  7.45855170e-03
#  -5.46411501e-03  2.53707422e-01  2.87209730e-02 -1.51804628e-01
#  -7.38625910e-02  1.41848452e-01 -4.49306525e-01 -1.15143442e-01
#  -3.71031409e-01  4.77779910e-01  1.82738926e-01  1.29521096e-01
#   1.85370990e-02 -3.46729249e-01  6.37821882e-01 -6.67331910e-02
#  -2.03831269e-01  1.17370392e-01 -1.91865606e-02 -4.59663748e-01
#   1.75080546e-01  5.82262581e-02  1.43324101e-01 -2.99478957e-02
#   3.10742919e-01  6.38662341e-02 -1.97299162e-01 -6.35355187e-02
#  -1.03719076e-02  3.45835709e-01  1.28664413e-01 -2.29552279e-02
#   1.43932452e-02  4.62034426e-01 -1.39910145e-03 -1.96111566e-01
#  -3.37063384e-02  2.78858068e-02  1.17951568e-01  4.47424987e-02
#  -4.56574869e-02 -4.07995714e-01  3.27716627e-02  2.07900937e-01
#  -1.49423974e-02  1.85415226e-01  1.33663788e-01  2.28393835e-01
#   1.55510292e-01 -1.93027939e-01 -3.59534999e-02 -3.80733084e-01
#  -4.25700751e-02  1.60869717e-01  2.42451987e-01  6.69814625e-02
#   4.15291625e-02  1.53320921e-01 -2.32052596e-01  6.21612058e-02
#  -2.32444514e-02  2.24443155e-01  2.06885622e-02 -1.26829300e-01
#   1.81533868e-01 -1.23672462e-01 -1.73034283e-01  6.34961411e-02
#   1.21280561e-01  1.51778380e-01 -5.12243134e-02 -7.71116803e-02
#  -2.39756831e-01 -7.08831485e-03  3.54059752e-01 -2.01210498e-02
#  -3.39756052e-01 -3.60407040e-01 -2.91524960e-01 -6.50946987e-02
#   8.79523071e-02  7.28969904e-02 -1.17790736e-01 -1.63457122e-01
#  -1.28598373e-01  3.42176366e-01  2.42163849e-01  8.28366324e-02
#  -3.02423435e-01  1.93681650e-01  2.45528415e-01 -1.44183833e-01]

# %%
tsne = TSNE(n_components=3)
t_data = tsne.fit_transform(weightPCA)

# %%
print(t_data.shape)
# Out:
# (13761, 3)

# %%
k = 4

# %%
y_ = kmeans(t_data,k)

# %%
Counter(y_)
# Out:
# Counter({0: 3237, 1: 3326, 2: 3774, 3: 3424})

# %%
print(y_[0:10])
# Out:
# [1 2 1 3 1 1 1 3 3 1]

# %%
last_X = []
last_Xb = []
last_Y = []
for index, i in enumerate(y_):
  last_X.append(X_cls1[index])
  last_Xb.append(Xb_cls1[index])
  if i == 0:
    last_Y.append('1')
  elif i == 1:
    last_Y.append('2')
  elif i == 2:
    last_Y.append('3')
  else:
    last_Y.append('4')

# %%
for index, i in enumerate(Y_o):
  last_X.append(X_o[index])
  last_Xb.append(Xb_o[index])
  if i == '0':
    last_Y.append('0')
  elif i == '9':
    last_Y.append('5')

# %%
print(len(last_X),len(last_Y))
print(last_X[0:5])
print(last_Xb[0:5])
print(last_Y[0:5])
# Out:
# 19978 19978
# ['新疆 板块 龙头 品种 持有', '强势 震荡', '算是 热门 板块 不错', '去年 妖股 突破 日 均线 短线 空间 打卡', '反弹 建议 先 出货']
# ['新疆 板块 龙头 品种 还 可 继续 持有 一下', '强势 震荡', '算是 热门 板块 之一 还 不错', '是 去年 的 要 妖股 之一 如果 突破 日 均线 短线 空间 将 被 打卡', '反弹 后 建议 先 出货']
# ['2', '3', '2', '4', '2']

# %%
cnt = Counter(last_Y)
print(cnt)
# Out:
# Counter({'5': 4392, '3': 3774, '4': 3424, '2': 3326, '1': 3237, '0': 1825})

# %%
my_dict = {0:last_Y,1:last_Xb,2:last_X}
new_df = pd.DataFrame(my_dict)

# %%
print(new_df.head())
# Out:
#    0                                       1                       2
# 0  2                新疆 板块 龙头 品种 还 可 继续 持有 一下          新疆 板块 龙头 品种 持有
# 1  3                                   强势 震荡                   强势 震荡
# 2  2                        算是 热门 板块 之一 还 不错             算是 热门 板块 不错
# 3  4  是 去年 的 要 妖股 之一 如果 突破 日 均线 短线 空间 将 被 打卡  去年 妖股 突破 日 均线 短线 空间 打卡
# 4  2                            反弹 后 建议 先 出货              反弹 建议 先 出货

# %%
new_df.to_csv("data2.csv",sep = "\t",index=None)
